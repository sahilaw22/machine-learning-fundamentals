# %% [markdown]
# **Basic Data Types**

# %% [markdown]
# Numeric Data Types

# %%
a = 5
print (type(a))
# Out:
# <class 'int'>

# %%
b = 5.5
print (type(b))

c = 2+5j
print (type(c))
# Out:
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# String Data Type
# Strings in Python can be created using single quotes, double quotes or even triple quotes.

# %%
s = 'Welcome to the Geeks World'
print(s)

# check data type
print(type(s))

# access string with index
print(s[1])
print(s[2])
print(s[-1])
# Out:
# Welcome to the Geeks World
# <class 'str'>
# e
# l
# d

# %% [markdown]
# List Data Type: can be created by just placing sequence inside the square brackets[].

# %%
# Empty list
a = []

# list with int values
a = [1, 2, 3]
print(a)

# list with mixed values int and String
b = ["Geeks", "For", "Geeks", 4, 5]
print(b)
# Out:
# [1, 2, 3]
# ['Geeks', 'For', 'Geeks', 4, 5]

# %%
a = ["Geeks", "For", "Geeks"]
print("Accessing element from the list")
print(a[0])
print(a[2])

print("Accessing element using negative indexing")
print(a[-1])
print(a[-3])
# Out:
# Accessing element from the list
# Geeks
# Geeks
# Accessing element using negative indexing
# Geeks
# Geeks

# %% [markdown]
# Tuple Data Type: created by placing a sequence of values separated by a ‘comma’ with or without the use of parentheses for grouping data sequence

# %%
# initiate empty tuple
tup1 = ()

tup2 = ('Geeks', 'For')
print("\nTuple with the use of String: ", tup2)
# Out:
# Tuple with the use of String:  ('Geeks', 'For')

# %%
tup1 = (1, 2, 3, 4, 5)

# access tuple items
print(tup1[0])
print(tup1[-1])
print(tup1[-3])
# Out:
# 1
# 5
# 3

# %% [markdown]
# Boolean Data Type: denoted by class bool. Boolean objects that are equal to True are truthy (true) and those equal to False are falsy (false)

# %%
print(type(True))
print(type(False))
print(type(true))
# Out:
# <class 'bool'>
# <class 'bool'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 print(type(True))
#       2 print(type(False))
# ----> 3 print(type(true))
#
# NameError: name 'true' is not defined

# %%
if 1:
    print("1 is truthy")

if not 0:
    print("0 is falsy")
# Out:
# 1 is truthy
# 0 is falsy

# %% [markdown]
# Set Data Type: unordered collection of data types that is iterable, mutable, and has no duplicate elements.
# Sets can be created by using the built-in set() function with an iterable object or a sequence by placing the sequence inside curly braces, separated by a ‘comma’.

# %%
# initializing empty set
s1 = set()

s1 = set("Geek")
print("Set with the use of String: ", s1)

s2 = set(["Geeks", "For", "Geeks", "For", "Geeks"])
print("Set with the use of List: ", s2)
# Out:
# Set with the use of String:  {'G', 'k', 'e'}
# Set with the use of List:  {'Geeks', 'For'}

# %%
set1 = set(["Geeks", "For", "Geeks"]) #Duplicates are removed automatically
print(set1)

# loop through set
for i in set1:
   print(i,end=" ") #prints elements one by one

# check if item exist in set
print("Geeks" in set1)
# Out:
# {'Geeks', 'For'}
# Geeks For True

# %% [markdown]
# Dictionary Data Type: holds a key: value pair
# Values in a dictionary can be of any datatype and can be duplicated, whereas keys can’t be repeated and must be immutable. The dictionary can also be created by the built-in function dict().

# %%
# initialize empty dictionary
d = {}

d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
print(d)

# creating dictionary using dict() constructor
d1 = dict({1: 'Geeks', 2: 'For', 3: 'Geeks'})
print(d1)
# Out:
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}

# %% [markdown]
# In order to access items of a dictionary refer to its key name. Key can be used inside square brackets. Using get() method we can access dictionary elements.

# %%
d = {1: 'Geeks', 'name': 'For', 3: 'Geeks'}

# Accessing an element using key
print(d["name"])

# Accessing a element using get
print(d.get("name"))

# key value pair using loop
for i in d:
    print(i, d[i])
# Out:
# For
# For
# 1 Geeks
# name For
# 3 Geeks
